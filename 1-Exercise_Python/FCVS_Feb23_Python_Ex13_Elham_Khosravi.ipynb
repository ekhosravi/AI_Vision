# %% [markdown]
# #                            Exercise 12

# %%
import pandas as pd

# %% [markdown]
# ### Exercise 01 :

# %%
df = pd.read_csv('cancer.csv')

# %% [markdown]
# ### Exercise 02 :

# %%
df.head()
# Out:
#         State  Total.Rate  Total.Number  Total.Population  Rates.Age.< 18  \
# 0     Alabama       214.2       71529.0        33387205.0             2.0
# 1      Alaska       128.1        6361.0         4966180.0             1.7
# 2     Arizona       165.6       74286.0        44845598.0             2.5
# 3    Arkansas       223.9       45627.0        20382448.0             2.3
# 4  California       150.9      393980.0       261135696.0             2.6
#
#    Rates.Age.18-45  Rates.Age.45-64  Rates.Age.> 64  \
# 0             18.5            244.7          1017.8
# 1             11.8            170.9           965.2
# 2             13.6            173.6           840.2
# 3             17.6            250.1          1048.3
# 4             13.7            163.7           902.4
#
#    Rates.Age and Sex.< 18.Female  Rates.Age and Sex.< 18.Male  ...  \
# 0                            2.0                          2.1  ...
# 1                            0.0                          0.0  ...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 75 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   State                                         51 non-null     object
#  1   Total.Rate                                    51 non-null     float64
#  2   Total.Number                                  51 non-null     float64
#  3   Total.Population                              51 non-null     float64
#  4   Rates.Age.< 18                                51 non-null     float64
#  5   Rates.Age.18-45                               51 non-null     float64
#  6   Rates.Age.45-64                               51 non-null     float64
#  7   Rates.Age.> 64                                51 non-null     float64
#  8   Rates.Age and Sex.< 18.Female                 51 non-null     float64
# ...

# %%
df.describe()
# Out:
#        Total.Rate   Total.Number  Total.Population  Rates.Age.< 18  \
# count   51.000000      51.000000      5.100000e+01       51.000000
# mean   190.656863   78723.725490      4.240151e+07        2.119608
# std     28.592155   80861.292676      4.784244e+07        0.502004
# min     98.500000    6361.000000      3.931624e+06        0.000000
# 25%    176.500000   20631.000000      1.186991e+07        2.050000
# 50%    196.100000   54930.000000      3.034806e+07        2.200000
# 75%    210.750000   93328.000000      4.650326e+07        2.400000
# max    254.600000  393980.000000      2.611357e+08        2.700000
#
#        Rates.Age.18-45  Rates.Age.45-64  Rates.Age.> 64  \
# count        51.000000        51.000000       51.000000
# mean         14.764706       197.576471      980.949020
# std           2.204343        31.261040       75.189556
# min          10.000000       132.300000      735.800000
# 25%          13.350000       175.000000      943.550000
# ...

# %% [markdown]
# ### Exercise 03 :

# %%
df.tail(13)
# Out:
#              State  Total.Rate  Total.Number  Total.Population  \
# 38    Pennsylvania       227.7      202230.0        88825682.0
# 39    Rhode Island       211.2       15570.0         7371636.0
# 40  South Carolina       202.6       65561.0        32366134.0
# 41    South Dakota       196.2       11212.0         5714307.0
# 42       Tennessee       213.1       94678.0        44430836.0
# 43           Texas       145.8      257000.0       176270421.0
# 44            Utah        98.5       19022.0        19321462.0
# 45         Vermont       211.6        9261.0         4377262.0
# 46        Virginia       177.1       99278.0        56054333.0
# 47      Washington       175.9       82864.0        47114240.0
# 48   West Virginia       254.6       32950.0        12940212.0
# 49       Wisconsin       197.5       78578.0        39788899.0
# 50         Wyoming       167.9        6603.0         3931624.0
#
#     Rates.Age.< 18  Rates.Age.18-45  Rates.Age.45-64  Rates.Age.> 64  \
# ...

# %% [markdown]
# ### Exercise 04 :

# %%
df1 = df[df['Total.Rate'] < 200]['State']
df1
# Out:
# 1                   Alaska
# 2                  Arizona
# 4               California
# 5                 Colorado
# 6              Connecticut
# 8     District of Columbia
# 10                 Georgia
# 11                  Hawaii
# 12                   Idaho
# 13                Illinois
# 16                  Kansas
# 20                Maryland
# 21           Massachusetts
# 23               Minnesota
# 26                 Montana
# 27                Nebraska
# 28                  Nevada
# 29           New Hampshire
# 30              New Jersey
# 31              New Mexico
# 32                New York
# 33          North Carolina
# 34            North Dakota
# 37                  Oregon
# 41            South Dakota
# 43                   Texas
# 44                    Utah
# 46                Virginia
# 47              Washington
# 49               Wisconsin
# 50                 Wyoming
# Name: State, dtype: object

# %%
df1.value_counts()
# Out:
# North Carolina          1
# Minnesota               1
# Hawaii                  1
# Illinois                1
# Colorado                1
# Alaska                  1
# Kansas                  1
# Arizona                 1
# Washington              1
# Montana                 1
# New Mexico              1
# District of Columbia    1
# Oregon                  1
# Nevada                  1
# Maryland                1
# Virginia                1
# California              1
# Wyoming                 1
# Texas                   1
# New Hampshire           1
# New York                1
# Idaho                   1
# Nebraska                1
# South Dakota            1
# Massachusetts           1
# North Dakota            1
# Georgia                 1
# Wisconsin               1
# Utah                    1
# New Jersey              1
# Connecticut             1
# Name: State, dtype: int64

# %% [markdown]
# ### Exercise 05 :

# %%
print(' number of states with total rate of less than 200 :' , df1.count())
# Out:
#  number of states with total rate of less than 200 : 31

# %% [markdown]
# ### Exercise 06 :

# %%
df.iloc[35:,14:29]
# Out:
#     Rates.Age and Sex.> 64.Female  Rates.Age and Sex.> 64.Male  \
# 35                          895.1                       1288.3
# 36                          855.6                       1279.4
# 37                          866.0                       1169.2
# 38                          898.6                       1276.5
# 39                          884.4                       1291.3
# 40                          775.1                       1195.1
# 41                          860.7                       1195.0
# 42                          834.4                       1294.7
# 43                          750.2                       1104.0
# 44                          611.6                        884.9
# 45                          872.8                       1165.8
# 46                          819.2                       1170.7
# 47                          852.4                       1142.0
# 48                          889.6                       1299.9
# ...

# %% [markdown]
# ### Exercise 07 :

# %%
df['Rates.Age.< 18'].unique()
# Out:
# array([2. , 1.7, 2.5, 2.3, 2.6, 1.9, 1.6, 2.2, 0. , 2.1, 2.4, 2.7, 1.4])

# %%
pd.DataFrame(df['Rates.Age.< 18'].unique())
# Out:
#       0
# 0   2.0
# 1   1.7
# 2   2.5
# 3   2.3
# 4   2.6
# 5   1.9
# 6   1.6
# 7   2.2
# 8   0.0
# 9   2.1
# 10  2.4
# 11  2.7
# 12  1.4

# %%
#pd.DataFrame(df['Rates.Age.< 18'].value_counts())

# %% [markdown]
# ### Exercise 08 :

# %%
df['Rates.Age.< 18'].mean()
# Out:
# 2.1196078431372554

# %% [markdown]
# ### Exercise 09 :

# %%
df.head()
# Out:
#         State  Total.Rate  Total.Number  Total.Population  Rates.Age.< 18  \
# 0     Alabama       214.2       71529.0        33387205.0             2.0
# 1      Alaska       128.1        6361.0         4966180.0             1.7
# 2     Arizona       165.6       74286.0        44845598.0             2.5
# 3    Arkansas       223.9       45627.0        20382448.0             2.3
# 4  California       150.9      393980.0       261135696.0             2.6
#
#    Rates.Age.18-45  Rates.Age.45-64  Rates.Age.> 64  \
# 0             18.5            244.7          1017.8
# 1             11.8            170.9           965.2
# 2             13.6            173.6           840.2
# 3             17.6            250.1          1048.3
# 4             13.7            163.7           902.4
#
#    Rates.Age and Sex.< 18.Female  Rates.Age and Sex.< 18.Male  ...  \
# 0                            2.0                          2.1  ...
# 1                            0.0                          0.0  ...
# ...

# %%
df_max = df['Total.Population'].max()
df_max
# Out:
# 261135696.0

# %%
pd.DataFrame(df['Total.Population'].map(lambda c : df_max - c)).head(10)
# Out:
#    Total.Population
# 0       227748491.0
# 1       256169516.0
# 2       216290098.0
# 3       240753248.0
# 4               0.0
# 5       225867962.0
# 6       236159807.0
# 7       254840433.0
# 8       256890337.0
# 9       128858625.0

# %%
df.head()
# Out:
#         State  Total.Rate  Total.Number  Total.Population  Rates.Age.< 18  \
# 0     Alabama       214.2       71529.0        33387205.0             2.0
# 1      Alaska       128.1        6361.0         4966180.0             1.7
# 2     Arizona       165.6       74286.0        44845598.0             2.5
# 3    Arkansas       223.9       45627.0        20382448.0             2.3
# 4  California       150.9      393980.0       261135696.0             2.6
#
#    Rates.Age.18-45  Rates.Age.45-64  Rates.Age.> 64  \
# 0             18.5            244.7          1017.8
# 1             11.8            170.9           965.2
# 2             13.6            173.6           840.2
# 3             17.6            250.1          1048.3
# 4             13.7            163.7           902.4
#
#    Rates.Age and Sex.< 18.Female  Rates.Age and Sex.< 18.Male  ...  \
# 0                            2.0                          2.1  ...
# 1                            0.0                          0.0  ...
# ...

# %%
# %ls
# Out:
#  Volume in drive C has no label.
#  Volume Serial Number is 202A-D7A9
#
#  Directory of C:\Users\intel\Music\Filoger\AI\Exercise
#
# 04/04/2023  07:49 AM    <DIR>          .
# 03/03/2023  09:13 PM    <DIR>          ..
# 04/03/2023  04:39 PM    <DIR>          .ipynb_checkpoints
# 04/03/2023  04:38 PM            30,422 cancer.csv
# 02/16/2023  05:29 PM            45,432 Exercises_01_Python.pdf
# 02/16/2023  05:32 PM           112,330 Exercises_02_Python.pdf
# 02/21/2023  07:26 PM            11,378 FCVS_Feb23_Python_Ex01_Elham_Khosravi.ipynb
# 02/21/2023  07:46 PM             5,684 FCVS_Feb23_Python_Ex02_Elham_Khosravi.ipynb
# 02/25/2023  09:36 AM             5,902 FCVS_Feb23_Python_Ex03_Elham_Khosravi.ipynb
# 02/28/2023  08:02 PM             6,553 FCVS_Feb23_Python_Ex04_Elham_Khosravi.ipynb
# 03/04/2023  06:20 PM            11,357 FCVS_Feb23_Python_Ex05_Elham_Khosravi.ipynb
# 03/04/2023  11:55 PM             9,794 FCVS_Feb23_Python_Ex06_Elham_Khosravi .ipynb
# ...
