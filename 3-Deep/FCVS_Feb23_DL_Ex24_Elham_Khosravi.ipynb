# %% [markdown]
# ## Excercise 24

# %%
import math
import numpy as np

# %% [markdown]
# ![Ex24-1.png](attachment:Ex24-1.png)

# %% [markdown]
# #### net_1_1 = w_1 * (x1 + x2 + x3 + x4) + b1
# #### O_1_1 = f1(net_1_1) = tanh (net_1_1)

# %%
net_1_1 = 3 * (2 + 1 + 1 + 0) + 1 
print (net_1_1)
# Out:
# 13

# %%
O_1_1 = math.tanh(net_1_1)
print (O_1_1)
# Out:
# 0.9999999999897818

# %% [markdown]
# #### net_1_2 = net_1_1 = w_1 * (x1 + x2 + x3 + x4) + b1
# #### O_1_2 = f1(net_1_2) = tanh (net_1_2)

# %%
net_1_2 = 3 * (2 + 1 + 1 + 0) + 1 
print (net_1_2)
# Out:
# 13

# %%
O_1_2 = math.tanh(net_1_2)
print (O_1_2)
# Out:
# 0.9999999999897818

# %%
net_1_3 = 3 * (2 + 1 + 1 + 0) + 1 
print (net_1_3)
# Out:
# 13

# %%
O_1_3 = math.tanh(net_1_3)
print (O_1_3)
# Out:
# 0.9999999999897818

# %% [markdown]
# #### net_2_1 = w_2 * (O_1_1 + O_1_2 + O_1_3) + b2
# #### O_2_1 = f2(net_2_1) = Relu (net_2_1)   ,  net_2_1>0 then O_2_1 = f2(net_2_1) = net_2_1

# %%
net_2_1 = 1 * (O_1_1 + O_1_2 + O_1_3) + 2 
print (net_2_1)
# Out:
# 4.999999999969345

# %%
O_2_1 = net_2_1
print (O_2_1)
# Out:
# 4.999999999969345

# %%
net_2_2 = net_2_1 = 1 * (O_1_1 + O_1_2 + O_1_3) + 2 
print (net_2_2)
# Out:
# 4.999999999969345

# %%
O_2_2 = net_2_2
print (O_2_2)
# Out:
# 4.999999999969345

# %% [markdown]
# #### net_3_1 = w_3 * (O_2_1 + O_2_2 ) + b3
# #### OUTPUT = O_3_1 = f3(net_3_1) = Sigmoid (net_3_1)

# %%
def sigmoid(x):
    return 1 / (1 + np.exp(-x))

# %%
net_3_1 = 1 * (O_2_1 + O_2_2 ) + 0  
print (net_3_1)
# Out:
# 9.99999999993869

# %%
OUTPUT = O_3_1 = sigmoid(net_3_1)
 
print("The OUTPUT result of this Neural Network is : {}".format(OUTPUT))
# Out:
# The OUTPUT result of this Neural Network is : 0.9999546021312947
