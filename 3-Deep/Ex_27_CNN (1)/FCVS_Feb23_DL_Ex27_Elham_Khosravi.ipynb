# %%
# baseline model with dropout and data augmentation on the cifar10 dataset
import sys
from matplotlib import pyplot
from keras.datasets import cifar10
from keras.utils import to_categorical
from keras.models import Sequential
from keras.layers import Conv2D
from keras.layers import MaxPooling2D
from keras.layers import Dense
from keras.layers import Flatten
from keras.preprocessing.image import ImageDataGenerator
from keras.layers import Dropout
from keras.layers import BatchNormalization
import matplotlib.pyplot as plt
import numpy as np
import cv2

# %%
# load train and test dataset
def load_dataset():
	# load dataset
	(trainX, trainY), (testX, testY) = cifar10.load_data()
	# one hot encode target values
	trainY = to_categorical(trainY)
	testY = to_categorical(testY)
	return trainX, trainY, testX, testY

# scale pixels
def prep_pixels(train, test):
	# convert from integers to floats
	train_norm = train.astype('float32')
	test_norm = test.astype('float32')
	# normalize to range 0-1
	train_norm = train_norm / 255.0
	test_norm = test_norm / 255.0
	# return normalized images
	return train_norm, test_norm

# %%
# define cnn model
def define_model():
	model = Sequential()
	model.add(Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same', input_shape=(32, 32, 3)))
	model.add(BatchNormalization())
	model.add(Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same'))
	model.add(BatchNormalization())
	model.add(MaxPooling2D((2, 2)))
	model.add(Dropout(0.2))
	model.add(Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same'))
	model.add(BatchNormalization())
	model.add(Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same'))
	model.add(BatchNormalization())
	model.add(MaxPooling2D((2, 2)))
	model.add(Dropout(0.3))
	model.add(Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same'))
	model.add(BatchNormalization())
	model.add(Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same'))
	model.add(BatchNormalization())
	model.add(MaxPooling2D((2, 2)))
	model.add(Dropout(0.4))
	model.add(Flatten())
	model.add(Dense(128, activation='relu', kernel_initializer='he_uniform'))
	model.add(BatchNormalization())
	model.add(Dropout(0.5))
	model.add(Dense(10, activation='softmax'))

	# compile model
	model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
	return model

# plot diagnostic learning curves
def summarize_diagnostics(history):
  # plot loss
  pyplot.subplot(211)
  pyplot.title('Cross Entropy Loss')
  pyplot.plot(history.history['loss'], color='blue', label='train')
  pyplot.plot(history.history['val_loss'], color='orange', label='test')
  # plot accuracy
  pyplot.subplot(212)
  pyplot.title('Classification Accuracy')
  pyplot.plot(history.history['accuracy'], color='blue', label='train')
  pyplot.plot(history.history['val_accuracy'], color='orange', label='test')

  pyplot.show()

  # save plot to file
  filename = sys.argv[0].split('/')[-1]
  pyplot.savefig(filename + '_plot.png')
  pyplot.close()

# %%
# load dataset
trainX, trainY, testX, testY = load_dataset()
# prepare pixel data
trainX, testX = prep_pixels(trainX, testX)
# define model
model = define_model()
# create data generator
datagen = ImageDataGenerator(width_shift_range=0.1, height_shift_range=0.1, horizontal_flip=True)
# prepare iterator
it_train = datagen.flow(trainX, trainY, batch_size=64)
# fit model
steps = int(trainX.shape[0] / 64)
history = model.fit(it_train, steps_per_epoch=steps, epochs=199, validation_data=(testX, testY), verbose=1)
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170498071/170498071 [==============================] - 3s 0us/step
# Epoch 1/199
# 781/781 [==============================] - 54s 50ms/step - loss: 1.7430 - accuracy: 0.3954 - val_loss: 1.4510 - val_accuracy: 0.4842
# Epoch 2/199
# 781/781 [==============================] - 34s 44ms/step - loss: 1.2597 - accuracy: 0.5465 - val_loss: 1.1655 - val_accuracy: 0.5975
# Epoch 3/199
# 781/781 [==============================] - 32s 41ms/step - loss: 1.0738 - accuracy: 0.6210 - val_loss: 0.9288 - val_accuracy: 0.6787
# Epoch 4/199
# 781/781 [==============================] - 32s 41ms/step - loss: 0.9555 - accuracy: 0.6656 - val_loss: 0.9160 - val_accuracy: 0.6915
# Epoch 5/199
# 781/781 [==============================] - 32s 40ms/step - loss: 0.8844 - accuracy: 0.6921 - val_loss: 0.7419 - val_accuracy: 0.7509
# Epoch 6/199
# 781/781 [==============================] - 32s 42ms/step - loss: 0.8226 - accuracy: 0.7132 - val_loss: 0.7195 - val_accuracy: 0.7504
# Epoch 7/199
# 781/781 [==============================] - 32s 41ms/step - loss: 0.7715 - accuracy: 0.7337 - val_loss: 0.6478 - val_accuracy: 0.7829
# Epoch 8/199
# 781/781 [==============================] - 32s 41ms/step - loss: 0.7266 - accuracy: 0.7507 - val_loss: 0.6716 - val_accuracy: 0.7705
# Epoch 9/199
# 781/781 [==============================] - 32s 41ms/step - loss: 0.7031 - accuracy: 0.7602 - val_loss: 0.6351 - val_accuracy: 0.7876
# Epoch 10/199
# 781/781 [==============================] - 33s 42ms/step - loss: 0.6662 - accuracy: 0.7731 - val_loss: 0.6931 - val_accuracy: 0.7712
# Epoch 11/199
# 781/781 [==============================] - 32s 41ms/step - loss: 0.6454 - accuracy: 0.7811 - val_loss: 0.5341 - val_accuracy: 0.8178
# Epoch 12/199
# 781/781 [==============================] - 32s 42ms/step - loss: 0.6189 - accuracy: 0.7884 - val_loss: 0.5053 - val_accuracy: 0.8289
# Epoch 13/199
# 781/781 [==============================] - 32s 40ms/step - loss: 0.5960 - accuracy: 0.7974 - val_loss: 0.6365 - val_accuracy: 0.7891
# Epoch 14/199
# 781/781 [==============================] - 32s 41ms/step - loss: 0.5871 - accuracy: 0.8013 - val_loss: 0.5539 - val_accuracy: 0.8119
# Epoch 15/199
# 781/781 [==============================] - 32s 41ms/step - loss: 0.5652 - accuracy: 0.8075 - val_loss: 0.5175 - val_accuracy: 0.8268
# Epoch 16/199
# 781/781 [==============================] - 32s 41ms/step - loss: 0.5578 - accuracy: 0.8111 - val_loss: 0.4625 - val_accuracy: 0.8425
# Epoch 17/199
# 781/781 [==============================] - 32s 41ms/step - loss: 0.
199
# 781/781 [==============================] - 32s 41ms/step - loss: 0.2731 - accuracy: 0.9063 - val_loss: 0.3231 - val_accuracy: 0.8951
# Epoch 141/199
# 781/781 [==============================] - 31s 40ms/step - loss: 0.2710 - accuracy: 0.9066 - val_loss: 0.3508 - val_accuracy: 0.8898
# Epoch 142/199
# 781/781 [==============================] - 32s 41ms/step - loss: 0.2707 - accuracy: 0.9078 - val_loss: 0.3509 - val_accuracy: 0.8898
# Epoch 143/199
# 781/781 [==============================] - 32s 41ms/step - loss: 0.2706 - accuracy: 0.9078 - val_loss: 0.3124 - val_accuracy: 0.8977
# Epoch 144/199
# 781/781 [==============================] - 31s 40ms/step - loss: 0.2687 - accuracy: 0.9075 - val_loss: 0.3351 - val_accuracy: 0.8944
# Epoch 145/199
# 781/781 [==============================] - 32s 40ms/step - loss: 0.2700 - accuracy: 0.9068 - val_loss: 0.3381 - val_accuracy: 0.8942
# Epoch 146/199
# 781/781 [==============================] - 31s 40ms/step - loss: 0.2680 - accuracy: 0.9089 - val_loss: 0.3281 - val_accuracy: 0.8951
# Epoch 147/199
# 781/781 [==============================] - 31s 40ms/step - loss: 0.2692 - accuracy: 0.9075 - val_loss: 0.3133 - val_accuracy: 0.8979
# Epoch 148/199
# 781/781 [==============================] - 32s 41ms/step - loss: 0.2664 - accuracy: 0.9077 - val_loss: 0.3514 - val_accuracy: 0.8874
# Epoch 149/199
# 781/781 [==============================] - 32s 41ms/step - loss: 0.2673 - accuracy: 0.9081 - val_loss: 0.3152 - val_accuracy: 0.8999
# Epoch 150/199
# 781/781 [==============================] - 33s 42ms/step - loss: 0.2632 - accuracy: 0.9104 - val_loss: 0.3036 - val_accuracy: 0.9032
# Epoch 151/199
# 781/781 [==============================] - 31s 40ms/step - loss: 0.2631 - accuracy: 0.9099 - val_loss: 0.3068 - val_accuracy: 0.9016
# Epoch 152/199
# 781/781 [==============================] - 32s 41ms/step - loss: 0.2650 - accuracy: 0.9090 - val_loss: 0.3096 - val_accuracy: 0.9026
# Epoch 153/199
# 781/781 [==============================] - 32s 41ms/step - loss: 0.2630 - accuracy: 0.9102 - val_loss: 0.3164 - val_accuracy: 0.9013
# Epoch 154/199
# 781/781 [==============================] - 31s 40ms/step - loss: 0.2646 - accuracy: 0.9087 - val_loss: 0.3272 - val_accuracy: 0.8960
# Epoch 155/199
# 781/781 [==============================] - 32s 40ms/step - loss: 0.2619 - accuracy: 0.9102 - val_loss: 0.3348 - val_accuracy: 0.8947
# Epoch 156/199
# 781/781 [==============================] - 32s 41ms/step - loss: 0.2624 - accuracy: 0.9099 - val_loss: 0.3042 - val_accuracy: 0.9025
# Epoch 157/199
# 781/781 [==============================] - 31s 40ms/step - loss: 0.2623 - accuracy: 0.9101 - val_loss: 0.3247 - val_accuracy: 0.8998
# Epoch 158/199
# 781/781 [==============================] - 32s 40ms/step - loss: 0.2611 - accuracy: 0.9107 - val_loss: 0.3640 - val_accuracy: 0.8861
# Epoch 159/199
# 781/781 [==============================] - 32s 41ms/step - loss: 0.2596 - accuracy: 0.9111 - val_loss: 0.3088 - val_accuracy: 0.9037
# Epoch 160/199
# 781/781 [==============================] - 31s 40ms/step - loss: 0.2603 - accuracy: 0.9108 - val_loss: 0.3341 - val_accuracy: 0.8948
# Epoch 161/199
# 781/781 [==============================] - 31s 40ms/step - loss: 0.2627 - accuracy: 0.9102 - val_loss: 0.3235 - val_accuracy: 0.8990
# Epoch 162/199
# 781/781 [==============================] - 32s 41ms/step - loss: 0.2615 - accuracy: 0.9099 - val_loss: 0.3137 - val_accuracy: 0.9024
# Epoch 163/199
# 781/781 [==============================] - 31s 40ms/step - loss: 0.2576 - accuracy: 0.9119 - val_loss: 0.3534 - val_accuracy: 0.8915
# Epoch 164/199
# 781/781 [==============================] - 32s 40ms/step - loss: 0.2608 - accuracy: 0.9088 - val_loss: 0.3001 - val_accuracy: 0.9040
# Epoch 165/199
# 781/781 [==============================] - 31s 40ms/step - loss: 0.2612 - accuracy: 0.9103 - val_loss: 0.3156 - val_accuracy: 0.9003
# Epoch 166/199
# 781/781 [==============================] - 31s 40ms/step - loss: 0.2585 - accuracy: 0.9119 - val_loss: 0.3221 - val_accuracy: 0.8973
# Epoch 167/199
# 781/781 [==============================] - 32s 41ms/step - loss: 0.2570 - accuracy: 0.9128 - val_loss: 0.3706 - val_accuracy: 0.8882
# Epoch 168/199
# 781/781 [==============================] - 32s 40ms/step - loss: 0.2612 - accuracy: 0.9093 - val_loss: 0.2970 - val_accuracy: 0.9053
# Epoch 169/199
# 781/781 [==============================] - 32s 41ms/step - loss: 0.2621 - accuracy: 0.9095 - val_loss: 0.3044 - val_accuracy: 0.9022
# Epoch 170/199
# 781/781 [==============================] - 32s 41ms/step - loss: 0.2566 - accuracy: 0.9110 - val_loss: 0.2990 - val_accuracy: 0.9046
# Epoch 171/199
# 781/781 [==============================] - 31s 40ms/step - loss: 0.2565 - accuracy: 0.9122 - val_loss: 0.3283 - val_accuracy: 0.8977
# Epoch 172/199
# 781/781 [==============================] - 32s 41ms/step - loss: 0.2555 - accuracy: 0.9118 - val_loss: 0.3148 - val_accuracy: 0.9040
# Epoch 173/199
# 781/781 [==============================] - 31s 39ms/step - loss: 0.2547 - accuracy: 0.9129 - val_loss: 0.3172 - val_accuracy: 0.8999
# Epoch 174/199
# 781/781 [==============================] - 31s 40ms/step - loss: 0.2536 - accuracy: 0.9113 - val_loss: 0.3375 - val_accuracy: 0.8969
# Epoch 175/199
# 781/781 [==============================] - 32s 41ms/step - loss: 0.2516 - accuracy: 0.9133 - val_loss: 0.3165 - val_accuracy: 0.9003
# Epoch 176/199
# 781/781 [==============================] - 31s 40ms/step - loss: 0.2533 - accuracy: 0.9131 - val_loss: 0.3293 - val_accuracy: 0.8971
# Epoch 177/199
# 781/781 [==============================] - 31s 40ms/step - loss: 0.2521 - accuracy: 0.9125 - val_loss: 0.3460 - val_accuracy: 0.8928
# Epoch 178/199
# 781/781 [==============================] - 32s 40ms/step - loss: 0.2501 - accuracy: 0.9149 - val_loss: 0.3090 - val_accuracy: 0.9030
# Epoch 179/199
# 781/781 [==============================] - 33s 42ms/step - loss: 0.2554 - accuracy: 0.9132 - val_loss: 0.3137 - val_accuracy: 0.9036
# Epoch 180/199
# 781/781 [==============================] - 31s 40ms/step - loss: 0.2539 - accuracy: 0.9115 - val_loss: 0.3139 - val_accuracy: 0.9002
# Epoch 181/199
# 781/781 [==============================] - 32s 41ms/step - loss: 0.2523 - accuracy: 0.9132 - val_loss: 0.2985 - val_accuracy: 0.9047
# Epoch 182/199
# 781/781 [==============================] - 31s 40ms/step - loss: 0.2483 - accuracy: 0.9142 - val_loss: 0.3217 - val_accuracy: 0.9010
# Epoch 183/199
# 781/781 [==============================] - 32s 40ms/step - loss: 0.2515 - accuracy: 0.9128 - val_loss: 0.3154 - val_accuracy: 0.9018
# Epoch 184/199
# 781/781 [==============================] - 32s 40ms/step - loss: 0.2476 - accuracy: 0.9139 - val_loss: 0.3012 - val_accuracy: 0.9036
# Epoch 185/199
# 781/781 [==============================] - 31s 40ms/step - loss: 0.2540 - accuracy: 0.9137 - val_loss: 0.3135 - val_accuracy: 0.8980
# Epoch 186/199
# 781/781 [==============================] - 32s 41ms/step - loss: 0.2458 - accuracy: 0.9157 - val_loss: 0.3326 - val_accuracy: 0.8955
# Epoch 187/199
# 781/781 [==============================] - 31s 40ms/step - loss: 0.2525 - accuracy: 0.9139 - val_loss: 0.3003 - val_accuracy: 0.9039
# Epoch 188/199
# 781/781 [==============================] - 31s 40ms/step - loss: 0.2511 - accuracy: 0.9135 - val_loss: 0.3220 - val_accuracy: 0.8985
# Epoch 189/199
# 781/781 [==============================] - 32s 41ms/step - loss: 0.2460 - accuracy: 0.9149 - val_loss: 0.3317 - val_accuracy: 0.8990
# Epoch 190/199
# 781/781 [==============================] - 31s 40ms/step - loss: 0.2496 - accuracy: 0.9140 - val_loss: 0.3388 - val_accuracy: 0.8987
# Epoch 191/199
# 781/781 [==============================] - 32s 41ms/step - loss: 0.2457 - accuracy: 0.9147 - val_loss: 0.3172 - val_accuracy: 0.9012
# Epoch 192/199
# 781/781 [==============================] - 32s 41ms/step - loss: 0.2479 - accuracy: 0.9138 - val_loss: 0.3448 - val_accuracy: 0.8930
# Epoch 193/199
# 781/781 [==============================] - 32s 41ms/step - loss: 0.2471 - accuracy: 0.9155 - val_loss: 0.3265 - val_accuracy: 0.8973
# Epoch 194/199
# 781/781 [==============================] - 31s 40ms/step - loss: 0.2444 - accuracy: 0.9162 - val_loss: 0.3194 - val_accuracy: 0.8974
# Epoch 195/199
# 781/781 [==============================] - 32s 41ms/step - loss: 0.2479 - accuracy: 0.9148 - val_loss: 0.3173 - val_accuracy: 0.9004
# Epoch 196/199
# 781/781 [==============================] - 32s 41ms/step - loss: 0.2423 - accuracy: 0.9161 - val_loss: 0.3265 - val_accuracy: 0.8985
# Epoch 197/199
# 781/781 [==============================] - 32s 41ms/step - loss: 0.2485 - accuracy: 0.9141 - val_loss: 0.3415 - val_accuracy: 0.8940
# Epoch 198/199
# 781/781 [==============================] - 32s 41ms/step - loss: 0.2488 - accuracy: 0.9145 - val_loss: 0.3167 - val_accuracy: 0.8993
# Epoch 199/199
# 781/781 [==============================] - 31s 40ms/step - loss: 0.2466 - accuracy: 0.9162 - val_loss: 0.3099 - val_accuracy: 0.9024

# %%
# evaluate model
_, acc = model.evaluate(testX, testY, verbose=0)
print('test accuracy is : > %.3f' % (acc * 100.0))
# learning curves
# Out:
# test accuracy is : > 90.240

# %%
summarize_diagnostics(history)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
model.save('/content/drive/MyDrive/cifar_model/cifar10_model_LastOk_200Epoch.h5')

# %%
def switch(lang):
  match lang:
      case 0:
          return("airplane")
      case 1:
          return("automobile")
      case 2:
          return("bird")
      case 3:
          return("cat")
      case 4:
          return("deer")
      case 5:
          return("dog")
      case 6:
          return("frog")
      case 7:
          return("horse")
      case 8:
          return("ship")
      case 9:
          return("truck")
      case _:
          print("The image isn't Valid")

# %%
def LoadSampleData(img_name):
  img = cv2.imread('/content/drive/MyDrive/AI_Deep/' + img_name )
  img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

  plt.subplot(1, 2, 1)
  plt.imshow(img)
  plt.axis('off')
  plt.title('main image')

  img_resized = cv2.resize(img, (32, 32))
  plt.subplot(1, 2, 2)
  plt.imshow(img_resized)
  plt.axis('off')
  img_flatten = img_resized.reshape(1, 32, 32,3)
  img_normalized = img_flatten.astype('float32')/255
  plt.title('prepared image')
  plt.show()

  preds = model.predict(img_normalized)
  print('\nprediction of model : \n' , preds)

  predicted_label = np.argmax(preds)
  print('\npredicted label is : ' ,  switch(predicted_label))

# %%
LoadSampleData('frog.jfif')
# Out:
# 1/1 [==============================] - 0s 389ms/step
#
# prediction of model :
#  [[1.6685126e-11 5.9351538e-12 3.2101499e-10 2.2966480e-09 9.2644191e-11
#   2.2646920e-10 1.0000000e+00 9.7463405e-11 1.6679144e-11 8.3754385e-11]]
#
# predicted label is :  frog

# %%
LoadSampleData('car.png')
# Out:
# 1/1 [==============================] - 0s 19ms/step
#
# prediction of model :
#  [[2.0154859e-07 8.4827531e-07 2.7970788e-08 1.5572782e-08 6.6963137e-09
#   7.2128876e-09 2.4478092e-07 4.2092164e-08 4.2384636e-07 9.9999809e-01]]
#
# predicted label is :  truck

# %%
def Load_Test_Image(indx):
  t_image = testX[indx].reshape(1, 32,32,3)
  preds = model.predict(t_image)
  print('\nprediction of model : \n' ,preds)

  predicted_label = np.argmax(preds)
  plt.imshow(testX[indx])
  print('\npredicted lable : ', switch(predicted_label))

# %%
Load_Test_Image(39)
# Out:
# 1/1 [==============================] - 0s 22ms/step
#
# prediction of model :
#  [[1.3046453e-09 5.9335550e-09 3.8143327e-08 1.6489557e-05 3.5300249e-07
#   9.9998271e-01 3.7949931e-08 2.7045104e-07 2.0603016e-08 2.3076833e-08]]
#
# predicted lable :  dog

# %%
Load_Test_Image(7655)
# Out:
# 1/1 [==============================] - 0s 30ms/step
#
# prediction of model :
#  [[1.9017411e-02 5.9353992e-05 9.0909823e-05 4.9915910e-05 3.2114247e-05
#   9.4886900e-06 9.9089884e-06 5.6005701e-06 9.8019224e-01 5.3311902e-04]]
#
# predicted lable :  ship

# %%
Load_Test_Image(765)
# Out:
# 1/1 [==============================] - 0s 22ms/step
#
# prediction of model :
#  [[8.4928303e-07 7.1746770e-10 9.9996650e-01 3.7861225e-06 2.3136303e-05
#   3.9903020e-06 1.6310051e-06 1.4897984e-07 2.8895657e-08 3.0196725e-09]]
#
# predicted lable :  bird
