# %% [markdown]
# ## Excercise 23

# %% [markdown]
# ![Ex23-1.png](attachment:Ex23-1.png)

# %% [markdown]
# #### net = wx + b    , output = f(net) = (net ** 2) + 8

# %%
net = (1.5 * 7) + 3 
print (net)
# Out:
# 13.5

# %%
output = (13.5 ** 2) + 8 
print (output)
# Out:
# 190.25

# %% [markdown]
# ![Ex23-2.png](attachment:Ex23-2.png)

# %% [markdown]
# #### net = w1x1 + w2x2 + w3x3 + b      ,    output = f(net) = (net ** 2) + 8

# %%
net = (1.5 * 7) + (4 * 5) + (3 * 2) + 3 
print (net)
# Out:
# 39.5

# %%
output = (39.5 ** 2) + 8 
print (output)
# Out:
# 1568.25
